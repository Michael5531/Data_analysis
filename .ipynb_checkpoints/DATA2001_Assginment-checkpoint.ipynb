# %%
import pandas as pd
data_healthservices = pd.read_csv('HealthServices.csv')
data_neighbourhoods = pd.read_csv('Neighbourhoods.csv')
data_nsw_postcodes = pd.read_csv('NSW_Postcodes.csv')
data_populationStats = pd.read_csv('PopulationStats2016.csv')
data_statisticalAreas = pd.read_csv('StatisticalAreas.csv')
data_covid19 = pd.read_csv('covid19_nsw_testsites_simulated_capacity.csv')

# %%
from sqlalchemy import create_engine
import psycopg2
import psycopg2.extras

def pgconnect():
    # please replace <your_unikey> and <your_SID> with your own details
    YOUR_UNIKEY = 'rulu6799'
    YOUR_PW     = '490443653'
    DB_LOGIN    = 'y20s1d2x01_'+YOUR_UNIKEY

    try:
        db = create_engine('postgres+psycopg2://'+DB_LOGIN+':'+YOUR_PW+'@soitpw11d59.shared.sydney.edu.au/'+DB_LOGIN, echo=False)
        conn = db.connect()
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
    return db,conn

# %%
db,conn = pgconnect()
# Out:
# unable to connect to the database
# (psycopg2.OperationalError) FATAL:  too many connections for database "y20s1d2x01_rulu6799"
#
# (Background on this error at: http://sqlalche.me/e/e3q8)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-37-582a0d7c10ea> in <module>
# ----> 1 db,conn = pgconnect()
#
# <ipython-input-36-ef11f99137d1> in pgconnect()
#      16         print("unable to connect to the database")
#      17         print(e)
# ---> 18     return db,conn
#
# UnboundLocalError: local variable 'conn' referenced before assignment

# %%
# if you want to reset the table
conn.execute("DROP TABLE IF EXISTS healhservices")


# 2nd: ensure that the schema is in place
HealthServices_schema = """CREATE TABLE IF NOT EXISTS healthservices (
                         id int,
                         name varchar(30),
                         category varchar(30),
                         num_beds float,
                         address varchar(60),
                         suburb varchar(20),
                         state varchar(4),
                         postcode char(4),
                         longitude float,
                         latitude float,
                         comment var(100),
                         website varchar(500),
                         primary key(id)
                   ); 
                   """
conn.execute("DROP TABLE IF EXISTS postcodes")
postcodes_schema = """CREATE TABLE IF NOT EXISTS postcodes (
                         id int,
                         postcode int,
                         locality varchar(30),
                         longitude float,
                         latitude float,
                         primary key(id)
                   ); 
                   """
conn.execute("DROP TABLE IF EXISTS populations")
populations_schema = """CREATE TABLE IF NOT EXISTS populations (
                        area_id int,
                        area_name varchar(30),
                        "age_0_4" int,
                        "age_5_9" int,
                        "age_10_14" int,
                        "age_15_19" int,
                        "age_20_24" int,
                        "age_25_29" int,
                        "age_30_34" int,
                        "age_35_39" int,
                        "age_40_44" int,
                        "age_45_49" int,
                        "age_50_54" int,
                        "age_55_59" int,
                        "age_60_64" int,
                        "age_65_69" int,
                        "age_70_74" int,
                        "age_75_79" int,
                        "age_80_84" int,
                        "age_85_and_over" int,
                        total_people int,
                        females int,
                        males int,
                        primary key(area_id)
                        )"""
conn.execute(HealthServices_schema)
conn.execute(postcodes_schema)
conn.execute(populations_schema)
# Verify that there are no existing tables
print(db.table_names())
# Out:
# ['healthservices', 'neighbourhoods', 'covid19', 'areas', 'sydney_neighbourhoods', 'neighbourhood_population_with_age_distribution', 'postcodes', 'populations', 'commute_table', 'spatial_ref_sys', 'postcodes_schema', 'sydney_areas']

# %%
conn.execute("DROP TABLE IF EXISTS neighbourhoods")
neighbourhoods_schema = """CREATE TABLE IF NOT EXISTS neighbourhoods (
                        area_id int,
                        area_name varchar(50),
                        land_area float,
                        population int,
                        number_of_dwellings int,
                        number_of_businesses int,
                        median_annual_household_income int,
                        avg_monthly_rent int,
                        primary key(area_id)
                        )"""
conn.execute(neighbourhoods_schema)
print(db.table_names())
# Out:
# ['postcodes', 'populations', 'neighbourhoods', 'covid19', 'areas', 'commute_table', 'spatial_ref_sys', 'postcodes_schema', 'healthservices', 'sydney_areas']

# %%
conn.execute("DROP TABLE IF EXISTS covid19")
neighbourhoods_schma = """CREATE TABLE IF NOT EXISTS covid19 (
                        site_id int,
                        "Centre name" varchar(50),
                        "Phone number" varchar(50),
                        "Opening hours" varchar(40),
                        longitude float,
                        latitude float,
                        test_capacity int,
                        primary key(site_id)
                        )"""
conn.execute(neighbourhoods_schma)
print(db.table_names())
# Out:
# ['postcodes', 'populations', 'neighbourhoods', 'covid19', 'areas', 'commute_table', 'spatial_ref_sys', 'postcodes_schema', 'healthservices', 'sydney_areas']

# %%
conn.execute("DROP TABLE IF EXISTS areas")
neighbourhoods_schma = """CREATE TABLE IF NOT EXISTS areas (
                        area_id int,
                        area_name varchar(80),
                        parent_area_id int
                        )"""
conn.execute(neighbourhoods_schma)
print(db.table_names())
# Out:
# ['postcodes', 'populations', 'neighbourhoods', 'covid19', 'areas', 'commute_table', 'spatial_ref_sys', 'postcodes_schema', 'healthservices', 'sydney_areas']

# %%
import pandas as pd
table_name = "healthservices"
data_healthservices.to_sql(table_name, con=conn, if_exists='replace')

# %%
import pandas as pd
table_name = "postcodes"
data_nsw_postcodes.to_sql(table_name, con=conn, if_exists='replace')

# %%
import pandas as pd
table_name = "populations"
data_populationStats.to_sql(table_name, con=conn, if_exists='replace')

# %%
import pandas as pd
table_name = "neighbourhoods"
data_neighbourhoods.to_sql(table_name, con=conn, if_exists='replace')

# %%
import pandas as pd
table_name = "covid19"
data_covid19.to_sql(table_name, con=conn, if_exists='replace')

# %%
import pandas as pd
table_name = "areas"
data_statisticalAreas.to_sql(table_name, con=conn, if_exists='replace')

# %% [markdown]
# **Task1 1. Sydney neighbourhood dataset**

# %%
conn.execute("DROP TABLE IF EXISTS sydney_neighbourhoods")
sydney_neighbourhoods_schema = """CREATE TABLE IF NOT EXISTS sydney_neighbourhoods (
                        index int,
                        area_id int,
                        area_name varchar(80),
                        land_area float,
                        population int,
                        number_of_dwellings int,
                        number_of_businesses int,
                        median_annual_household_income int,
                        avg_monthly_rent int
)"""
conn.execute(sydney_neighbourhoods_schema)
print(db.table_names())
# Out:
# ['healthservices', 'postcodes', 'populations', 'neighbourhoods', 'covid19', 'areas', 'sydney_neighbourhoods', 'commute_table', 'spatial_ref_sys', 'postcodes_schema', 'sydney_areas']

# %%
conn.execute("""
    INSERT INTO sydney_neighbourhoods
        SELECT n.index, n.area_id, n.area_name, land_area, population, 
        number_of_dwellings, number_of_businesses, 
        median_annual_household_income, avg_monthly_rent
        FROM neighbourhoods n LEFT JOIN areas a ON (n.area_id = a.area_id)
        WHERE CAST(n.area_id as varchar(100)) LIKE '102%'
           OR CAST(n.area_id as varchar(100)) LIKE '115%'
           OR CAST(n.area_id as varchar(100)) LIKE '116%'
           OR CAST(n.area_id as varchar(100)) LIKE '117%'
           OR CAST(n.area_id as varchar(100)) LIKE '118%'
           OR CAST(n.area_id as varchar(100)) LIKE '119%'
           OR CAST(n.area_id as varchar(100)) LIKE '120%'
           OR CAST(n.area_id as varchar(100)) LIKE '121%'
           OR CAST(n.area_id as varchar(100)) LIKE '122%'
           OR CAST(n.area_id as varchar(100)) LIKE '123%'
           OR CAST(n.area_id as varchar(100)) LIKE '124%'
           OR CAST(n.area_id as varchar(100)) LIKE '125%'
           OR CAST(n.area_id as varchar(100)) LIKE '126%'
           OR CAST(n.area_id as varchar(100)) LIKE '127%'
           OR CAST(n.area_id as varchar(100)) LIKE '128%'
""")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-48d187a69b12> in <module>
#      20            OR CAST(n.area_id as varchar(100)) LIKE '127%'
#      21            OR CAST(n.area_id as varchar(100)) LIKE '128%'
# ---> 22 """)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
# -> 1475                 util.reraise(*exc_info)
#    1476
#    1477         finally:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     151         if value.__traceback__ is not tb:
#     152             raise value.with_traceback(tb)
# --> 153         raise value
#     154
#     155     def u(s):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# TypeError: 'dict' object does not support indexing

# %% [markdown]
# **Task1 2. Census data for the given neighbourhoods including population count and age distributions**

# %%
conn.execute("DROP TABLE IF EXISTS neighbourhood_population_with_age_distribution")
neighbourhood_population_with_age_distribution_schma = """CREATE TABLE IF NOT EXISTS neighbourhood_population_with_age_distribution (
                        index int,
                        area_id int,
                        area_name varchar(80),
                        population int,
                        "age_0_4" int,
                        "age_5_9" int,
                        "age_10_14" int,
                        "age_15_19" int,
                        "age_20_24" int,
                        "age_25_29" int,
                        "age_30_34" int,
                        "age_35_39" int,
                        "age_40_44" int,
                        "age_45_49" int,
                        "age_50_54" int,
                        "age_55_59" int,
                        "age_60_64" int,
                        "age_65_69" int,
                        "age_70_74" int,
                        "age_75_79" int,
                        "age_80_84" int,
                        "age_85_and_over" int,
                        total_people int
                        )"""
conn.execute(HealthServices_schema)
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# InsufficientPrivilege: must be owner of table neighbourhood_population_with_age_distribution
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-6ba5fa632e88> in <module>
# ----> 1 conn.execute("DROP TABLE IF EXISTS neighbourhood_population_with_age_distribution")
#       2 neighbourhood_population_with_age_distribution_schma = """CREATE TABLE IF NOT EXISTS neighbourhood_population_with_age_distribution (
#       3                         index int,
#       4                         area_id int,
#       5                         area_name varchar(80),
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.InsufficientPrivilege) must be owner of table neighbourhood_population_with_age_distribution
#
# [SQL: DROP TABLE IF EXISTS neighbourhood_population_with_age_distribution]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
conn.execute("""
    INSERT INTO neighbourhood_population_with_age_distribution
    SELECT n.index, n.area_id, n.area_name, n.population,
    p."age_0_4", p."age_5_9", p."age_10_14", p."age_15_19", 
    p."age_20_24", p."age_25_29" int, p."age_30_34", 
    p."age_35_39", p."age_40_44", p."age_45_49", p."age_50_54",
    p."age_55_59", p."age_60_64", p."age_65_69", p."age_70_74",
    p."age_75_79", p."age_80_84", p."age_85_and_over", p.totaL_people 
    FROM populations p JOIN neighbourhoods n ON (p.area_id = n.area_id) JOIN areas a ON (n.area_id = a.area_id)
""")
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# SyntaxError: syntax error at or near "int"
# LINE 5:     p."age_20_24", p."age_25_29" int, p."age_30_34",
#                                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-28-b64cb44c9e3d> in <module>
#       8     p."age_75_79", p."age_80_84", p."age_85_and_over", p.totaL_people
#       9     FROM populations p JOIN neighbourhoods n ON (p.area_id = n.area_id) JOIN areas a ON (n.area_id = a.area_id)
# ---> 10 """)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.SyntaxError) syntax error at or near "int"
# LINE 5:     p."age_20_24", p."age_25_29" int, p."age_30_34",
#                                          ^
#
# [SQL:
#     INSERT INTO neighbourhood_population_with_age_distribution
#     SELECT n.index, n.area_id, n.area_name, n.population,
#     p."age_0_4", p."age_5_9", p."age_10_14", p."age_15_19",
#     p."age_20_24", p."age_25_29" int, p."age_30_34",
#     p."age_35_39", p."age_40_44", p."age_45_49", p."age_50_54",
#     p."age_55_59", p."age_60_64", p."age_65_69", p."age_70_74",
#     p."age_75_79", p."age_80_84", p."age_85_and_over", p.totaL_people
#     FROM populations p JOIN neighbourhoods n ON (p.area_id = n.area_id) JOIN areas a ON (n.area_id = a.area_id)
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %% [markdown]
# ## Task1 Spatial Join

# %% [markdown]
# **Module setup**

# %%
from __future__ import (absolute_import, division, print_function)
import os
import json

import matplotlib as mpl
import matplotlib.pyplot as plt

from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
from geopandas import GeoSeries, GeoDataFrame

data_path = "./sa2"

# %% [markdown]
# **Loading Shapefile data - with GeoPandas**

# %%
import geopandas as gpd
regions = gpd.read_file( os.path.join(data_path, "SA2_2016_AUST.shp") )
print("#regions: ", len(regions))
# Out:
# #regions:  2310

# %%
regions.head()
# Out:
#   SA2_MAIN16 SA2_5DIG16         SA2_NAME16 SA3_CODE16  SA3_NAME16 SA4_CODE16  \
# 0  101021007      11007          Braidwood      10102  Queanbeyan        101
# 1  101021008      11008            Karabar      10102  Queanbeyan        101
# 2  101021009      11009         Queanbeyan      10102  Queanbeyan        101
# 3  101021010      11010  Queanbeyan - East      10102  Queanbeyan        101
# 4  101021011      11011  Queanbeyan Region      10102  Queanbeyan        101
#
#        SA4_NAME16 GCC_CODE16   GCC_NAME16 STE_CODE16       STE_NAME16  \
# 0  Capital Region      1RNSW  Rest of NSW          1  New South Wales
# 1  Capital Region      1RNSW  Rest of NSW          1  New South Wales
# 2  Capital Region      1RNSW  Rest of NSW          1  New South Wales
# 3  Capital Region      1RNSW  Rest of NSW          1  New South Wales
# 4  Capital Region      1RNSW  Rest of NSW          1  New South Wales
#
#    AREASQKM16                                           geometry
# 0   3418.3525  POLYGON ((149.58423 -35.44427, 149.58444 -35.4...
# 1      6.9825  POLYGON ((149.21898 -35.36739, 149.21799 -35.3...
# 2      4.7634  POLYGON ((149.21325 -35.34325, 149.21619 -35.3...
# 3     13.0034  POLYGON ((149.24033 -35.34782, 149.24023 -35.3...
# 4   3054.4099  POLYGON ((149.23580 -35.38738, 149.23771 -35.3...

# %%
regions.head().geom_type
# Out:
# 0    Polygon
# 1    Polygon
# 2    Polygon
# 3    Polygon
# 4    Polygon
# dtype: object

# %% [markdown]
# **Writing Geo-Shaped Data to a Database and PostGIS Querying**

# %%
import psycopg2
import psycopg2.extras

def pgconnect(credential_filepath):
    try:
        with open(credential_filepath) as f:
            db_conn_dict = json.load(f)
        conn = psycopg2.connect(**db_conn_dict)
        print('connected')
    except Exception as e:
        print("unable to connect to the database")
        print(e)
        return None
    return conn
data_path_json = "./"
# please update the details in data2x01_db.json
credfilepath = os.path.join(data_path_json, "data2x01_db.json")
# credfilepath = os.path.join(data_path, "data2001_dbadmin.json")
# credfilepath = os.path.join(data_path, "data2001_db95.json")
conn = pgconnect(credfilepath)
# Out:
# connected

# %% [markdown]
# **Store Geo-data to PostgreSQL Dasebase with PostGIS**

# %%
def pgquery( conn, sqlcmd, args=None, msg=False, returntype='tuple'):
    """ utility function to execute some SQL query statement
        it can take optional arguments (as a dictionary) to fill in for placeholders in the SQL
        will return the complete query result as return value - or in case of error: None
        error and transaction handling built-in (by using the 'with' clauses)"""
    retval = None
    with conn:
        cursortype = None if returntype != 'dict' else psycopg2.extras.RealDictCursor
        with conn.cursor(cursor_factory=cursortype) as cur:
            try:
                if args is None:
                    cur.execute(sqlcmd)
                else:
                    cur.execute(sqlcmd, args)
                if (cur.description != None ):
                    retval = cur.fetchall() # we use fetchall() as we expect only _small_ query results
                if msg != False:
                    print("success: " + msg)
            except psycopg2.DatabaseError as e:
                if e.pgcode != None:
                    if msg: print("db read error: "+msg)
                    print(e)
            except Exception as e:
                print(e)
    return retval

# %% [markdown]
# **Create schema for shapefile data**

# %%
# lets just make sure we have PostGIS working on our connection
postgis_check = '''
SELECT PostGIS_Version();
'''

pgquery(conn,postgis_check)
# Out:
# [('3.0 USE_GEOS=1 USE_PROJ=1 USE_STATS=1',)]

# %%
sydney_areas_schema = '''CREATE TABLE sydney_areas (
                  SA2_mean varchar(200),
                  SA2_id varchar(200),
                  SA2_name varchar(200),
                  SA3_id varchar(200),
                  SA3_name varchar(200),
                  SA4_id varchar(200),
                  SA4_name varchar(200),
                  GCC_id varchar(200),
                  GCC_name varchar(200),
                  STE_id varchar(200),
                  STE_name varchar(200),
                  areas float,
                  geometry GEOMETRY(MULTIPOLYGON,4326))''' 

pgquery(conn, "DROP TABLE IF EXISTS sydney_areas", msg="cleared old table")
pgquery(conn, sydney_areas_schema, msg="created sydney_areas table")
# Out:
# success: cleared old table
# success: created sydney_areas table

# %% [markdown]
# **Once the table has been created, load the data into the table**

# %%
insert_stmt = """INSERT INTO sydney_areas VALUES ( %(SA2_MAIN16)s, %(SA2_5DIG16)s, %(SA2_NAME16)s, %(SA3_CODE16)s, 
                                            %(SA3_NAME16)s, %(SA4_CODE16)s, %(SA4_NAME16)s, %(GCC_CODE16)s,
                                            %(GCC_NAME16)s, %(STE_CODE16)s, %(STE_NAME16)s,%(AREASQKM16)s,
                                            ST_Multi(ST_GeomFromText(%(geom_wkt)s, 4326)) )"""

# create a new column called 'geom_wkt' with the "Well Known Text-Format (WKT)" of each geometry; used by SQL insert
regions['geom_wkt'] = regions['geometry'].apply(lambda x: x.wkt if x is not None else x)

# insert all regions using above's SQL Insert statement into the database
for idx, region in regions.iterrows():
    pgquery(conn, insert_stmt, args=region, msg="inserted "+str(region['SA2_NAME16']))
# Out:
# success: inserted Braidwood
# success: inserted Karabar
# success: inserted Queanbeyan
# success: inserted Queanbeyan - East
# success: inserted Queanbeyan Region
# success: inserted Queanbeyan West - Jerrabomberra
# success: inserted Bombala
# success: inserted Cooma
# success: inserted Cooma Region
# success: inserted Jindabyne - Berridale
# success: inserted Batemans Bay
# success: inserted Batemans Bay - South
# success: inserted Bega - Tathra
# success: inserted Bega-Eden Hinterland
# success: inserted Broulee - Tomakin
# success: inserted Deua - Wadbilliga
# success: inserted Eden
# success: inserted Eurobodalla Hinterland
# success: inserted Merimbula - Tura Beach
# success: inserted Moruya - Tuross Head
# success: inserted Narooma - Bermagui
# success: inserted Goulburn
# success: inserted Goulburn Region
# success: inserted Yass
# success: inserted Yass Region
# success: inserted Young
# success: inserted Young Region
# success: inserted Avoca Beach - Copacabana
# success: inserted Box Head - MacMasters Beach
# success: inserted Calga - Kulnura
# success: inserted Erina - Green Point
# success: inserted Gosford - Springfield
# success: inserted Kariong
# success: inserted Kincumber - Picketts Valley
# success: inserted Narara
# success: inserted Niagara Park - Lisarow
# success: inserted Point Clare - Koolewong
# success: inserted Saratoga - Davistown
# success: inserted Terrigal - North Avoca
# success: inserted Umina - Booker Bay - Patonga
# success: inserted Wamberal - Forresters Beach
# success: inserted Woy Woy - Blackwall
# success: inserted Wyoming
# success: inserted Bateau Bay - Killarney Vale
# success: inserted Blue Haven - San Remo
# success: inserted Budgewoi - Buff Point - Halekulani
# success: inserted Chittaway Bay - Tumbi Umbi
# success: inserted Gorokan - Kanwal - Charmhaven
# success: inserted Jilliby - Yarramalong
# success: inserted Lake Munmorah - Mannering Park
# success: inserted Ourimbah - Fountaindale
# success: inserted Summerland Point - Gwandalan
# success: inserted The Entrance
# success: inserted Toukley - Norah Head
# success: inserted Tuggerah - Kangy Angy
# success: inserted Warnervale - Wadalba
# success: inserted Wyong
# success: inserted Bathurst
# success: inserted Bathurst - East
# success: inserted Bathurst Region
# success: inserted Oberon
# success: inserted Condobolin
# success: inserted Cowra
# success: inserted Cowra Region
# success: inserted Forbes
# success: inserted Grenfell
# success: inserted Parkes (NSW)
# success: inserted Parkes Region
# success: inserted West Wyalong
# success: inserted Lithgow
# success: inserted Lithgow Region
# success: inserted Mudgee
# success: inserted Mudgee Region - East
# success: inserted Mudgee Region - West
# success: inserted Wollangambe - Wollemi
# success: inserted Blayney
# success: inserted Orange
# success: inserted Orange - North
# success: inserted Orange Region
# success: inserted Grafton
# success: inserted Grafton Region
# success: inserted Maclean - Yamba - Iluka
# success: inserted Bellingen
# success: inserted Coffs Harbour - North
# success: inserted Coffs Harbour - South
# success: inserted Coramba - Nana Glen - Bucca
# success: inserted Dorrigo
# success: inserted Korora - Emerald Beach
# success: inserted Sawtell - Boambee
# success: inserted Urunga
# success: inserted Woolgoolga - Arrawarra
# success: inserted Bourke - Brewarrina
# success: inserted Cobar
# success: inserted Coonamble
# success: inserted Nyngan - Warren
# success: inserted Walgett - Lightning Ridge
# success: inserted Broken Hill
# success: inserted Far West
# success: inserted Coonabarabran
# success: inserted Dubbo - East
# success: inserted Dubbo - South
# success: inserted Dubbo - West
# success: inserted Dubbo Region
# success: inserted Gilgandra
# success: inserted Narromine
# success: inserted Wellington
# success: inserted Branxton - Greta - Pokolbin
# success: inserted Cessnock
# success: inserted Cessnock Region
# success: inserted Dungog
# success: inserted Kurri Kurri - Abermain
# success: inserted Singleton
# success: inserted Singleton Region
# success: inserted Maitland
# success: inserted Maitland - East
# success: inserted Maitland - North
# success: inserted Maitland - West
# success: inserted Thornton - Millers Forest
# success: inserted Anna Bay
# success: inserted Lemon Tree Passage - Tanilba Bay
# success: inserted Nelson Bay Peninsula
# success: inserted Raymond Terrace
# success: inserted Seaham - Woodville
# success: inserted Tea Gardens - Hawks Nest
# success: inserted Williamtown - Medowie - Karuah
# success: inserted Muswellbrook
# success: inserted Muswellbrook Region
# success: inserted Scone
# success: inserted Scone Region
# success: inserted Dapto - Avondale
# success: inserted Horsley - Kembla Grange
# success: inserted Port Kembla Industrial
# success: inserted Unanderra - Mount Kembla
# success: inserted Berkeley - Lake Heights - Cringila
# success: inserted Port Kembla - Warrawong
# success: inserted Windang - Primbee
# success: inserted Illawarra Catchment Reserve
# success: inserted Albion Park - Macquarie Pass
# success: inserted Albion Park Rail
# success: inserted Kiama
# success: inserted Kiama Downs - Minnamurra
# success: inserted Kiama Hinterland - Gerringong
# success: inserted Shellharbour - Flinders
# success: inserted Shellharbour - Oak Flats
# success: inserted Warilla
# success: inserted Balgownie - Fairy Meadow
# success: inserted Corrimal - Tarrawanna - Bellambi
# success: inserted Figtree - Keiraville
# success: inserted Helensburgh
# success: inserted Thirroul - Austinmer - Coalcliff
# success: inserted Woonona - Bulli - Russell Vale
# success: inserted Wollongong - East
# success: inserted Wollongong - West
# success: inserted Bulahdelah - Stroud
# success: inserted Forster
# success: inserted Forster-Tuncurry Region
# success: inserted Tuncurry
# success: inserted Kempsey
# success: inserted Kempsey Region
# success: inserted Macksville - Scotts Head
# success: inserted Nambucca Heads
# success: inserted Nambucca Heads Region
# success: inserted South West Rocks
# success: inserted Lord Howe Island
# success: inserted Laurieton - Bonny Hills
# success: inserted Port Macquarie - East
# success: inserted Port Macquarie - West
# success: inserted Port Macquarie Region
# success: inserted Wauchope
# success: inserted Gloucester
# success: inserted Newtown (Vic.)
# success: inserted North Geelong - Bell Park
# success: inserted Clifton Springs
# success: inserted Lorne - Anglesea
# success: inserted Ocean Grove - Barwon Heads
# success: inserted Portarlington
# success: inserted Point Lonsdale - Queenscliff
# success: inserted Torquay
# success: inserted Alexandra
# success: inserted Euroa
# success: inserted Kilmore - Broadford
# success: inserted Mansfield (Vic.)
# success: inserted Nagambie
# success: inserted Seymour
# success: inserted Seymour Region
# success: inserted Upper Yarra Valley
# success: inserted Yea
# success: inserted Benalla
# success: inserted Benalla Region
# success: inserted Rutherglen
# success: inserted Wangaratta
# success: inserted Wangaratta Region
# success: inserted Beechworth
# success: inserted Bright - Mount Beauty
# success: inserted Chiltern - Indigo Valley
# success: inserted Myrtleford
# success: inserted Towong
# success: inserted West Wodonga
# success: inserted Wodonga
# success: inserted Yackandandah
# success: inserted Drouin
# success: inserted Mount Baw Baw Region
# success: inserted Trafalgar (Vic.)
# success: inserted Warragul
# success: inserted Alps - East
# success: inserted Bairnsdale
# success: inserted Bruthen - Omeo
# success: inserted Lake King
# success: inserted Lakes Entrance
# success: inserted Orbost
# success: inserted Paynesville
# success: inserted Foster
# success: inserted French Island
# success: inserted Korumburra
# success: inserted Leongatha
# success: inserted Phillip Island
# success: inserted Wilsons Promontory
# success: inserted Wonthaggi - Inverloch
# success: inserted Churchill
# success: inserted Moe - Newborough
# success: inserted Morwell
# success: inserted Traralgon
# success: inserted Yallourn North - Glengarry
# success: inserted Alps - West
# success: inserted Longford - Loch Sport
# success: inserted Maffra
# success: inserted Rosedale
# success: inserted Sale
# success: inserted Yarram
# success: inserted Brunswick
# success: inserted Brunswick East
# success: inserted Brunswick West
# success: inserted Coburg
# success: inserted Pascoe Vale South
# success: inserted Alphington - Fairfield
# success: inserted Northcote
# success: inserted Thornbury
# success: inserted Ascot Vale
# success: inserted Essendon - Aberfeldie
# success: inserted Flemington
# success: inserted Moonee Ponds
# success: inserted Carlton
# success: inserted Docklands
# success: inserted East Melbourne
# success: inserted Flemington Racecourse
# success: inserted Kensington (Vic.)
# success: inserted Melbourne
# success: inserted North Melbourne
# success: inserted Parkville
# success: inserted South Yarra - West
# success: inserted Southbank
# success: inserted West Melbourne
# success: inserted Albert Park
# success: inserted Elwood
# success: inserted Port Melbourne
# success: inserted Port Melbourne Industrial
# success: inserted South Melbourne
# success: inserted St Kilda
# success: inserted St Kilda East
# success: inserted Armadale
# success: inserted Prahran - Windsor
# success: inserted South Yarra - East
# success: inserted Toorak
# success: inserted Abbotsford
# success: inserted Carlton North - Princes Hill
# success: inserted Collingwood
# success: inserted Fitzroy
# success: inserted Fitzroy North
# success: inserted Richmond (Vic.)
# success: inserted Yarra - North
# success: inserted Ashburton (Vic.)
# success: inserted Balwyn
# success: inserted Balwyn North
# success: inserted Camberwell
# success: inserted Glen Iris - East
# success: inserted Hawthorn
# success: inserted Hawthorn East
# success: inserted Kew
# success: inserted Kew East
# success: inserted Surrey Hills (West) - Canterbury
# success: inserted Bulleen
# success: inserted Doncaster
# success: inserted Templestowe
# success: inserted Templestowe Lower
# success: inserted Doncaster East (North)
# success: inserted Doncaster East (South)
# success: inserted Blackburn
# success: inserted Blackburn South
# success: inserted Box Hill
# success: inserted Box Hill North
# success: inserted Burwood
# success: inserted Burwood East
# success: inserted Surrey Hills (East) - Mont Albert
# success: inserted Beaumaris
# success: inserted Brighton (Vic.)
# success: inserted Brighton East
# success: inserted Cheltenham - Highett (West)
# success: inserted Hampton
# success: inserted Sandringham - Black Rock
# success: inserted Bentleigh - McKinnon
# success: inserted Carnegie
# success: inserted Caulfield - North
# success: inserted Caulfield - South
# success: inserted Elsternwick
# success: inserted Hughesdale
# success: inserted Murrumbeena
# success: inserted Ormond - Glen Huntly
# success: inserted Bentleigh East (North)
# success: inserted Bentleigh East (South)
# success: inserted Aspendale Gardens - Waterways
# success: inserted Braeside
# success: inserted Carrum - Patterson Lakes
# success: inserted Chelsea - Bonbeach
# success: inserted Chelsea Heights
# success: inserted Cheltenham - Highett (East)
# success: inserted Edithvale - Aspendale
# success: inserted Mentone
# success: inserted Moorabbin - Heatherton
# success: inserted Moorabbin Airport
# success: inserted Mordialloc - Parkdale
# success: inserted Malvern - Glen Iris
# success: inserted Malvern East
# success: inserted Bundoora - East
# success: inserted Greensborough
# success: inserted Heidelberg - Rosanna
# success: inserted Heidelberg West
# success: inserted Ivanhoe
# success: inserted Ivanhoe East - Eaglemont
# success: inserted Montmorency - Briar Hill
# success: inserted Viewbank - Yallambie
# success: inserted Watsonia
# success: inserted Kingsbury
# success: inserted Reservoir - East
# success: inserted Reservoir - West
# success: inserted Preston - East
# success: inserted Preston - West
# success: inserted Eltham
# success: inserted Hurstbridge
# success: inserted Kinglake
# success: inserted Panton Hill - St Andrews
# success: inserted Plenty - Yarrambat
# success: inserted Research - North Warrandyte
# success: inserted Wattle Glen - Diamond Creek
# success: inserted Bundoora - North
# success: inserted Bundoora - West
# success: inserted Lalor
# success: inserted Mill Park - North
# success: inserted Mill Park - South
# success: inserted Thomastown
# success: inserted Wallan
# success: inserted Whittlesea
# success: inserted Doreen
# success: inserted Epping - East
# success: inserted Epping - South
# success: inserted Epping - West
# success: inserted Mernda
# success: inserted South Morang (North)
# success: inserted South Morang (South)
# success: inserted Wollert
# success: inserted Airport West
# success: inserted Essendon Airport
# success: inserted Keilor
# success: inserted Keilor East
# success: inserted Niddrie - Essendon West
# success: inserted Strathmore
# success: inserted Gisborne
# success: inserted Macedon
# success: inserted Riddells Creek
# success: inserted Romsey
# success: inserted Coburg North
# success: inserted Fawkner
# success: inserted Pascoe Vale
# success: inserted Glenroy
# success: inserted Gowanbrae
# success: inserted Hadfield
# success: inserted Sunbury
# success: inserted Sunbury - South
# success: inserted Broadmeadows
# success: inserted Campbellfield - Coolaroo
# success: inserted Gladstone Park - Westmeadows
# success: inserted Greenvale - Bulla
# success: inserted Meadow Heights
# success: inserted Melbourne Airport
# success: inserted Roxburgh Park - Somerton
# success: inserted Sunshine West
# success: inserted Sydenham
# success: inserted Taylors Lakes
# success: inserted Altona
# success: inserted Altona Meadows
# success: inserted Altona North
# success: inserted Newport
# success: inserted Seabrook
# success: inserted Williamstown
# success: inserted Braybrook
# success: inserted Footscray
# success: inserted Maribyrnong
# success: inserted Seddon - Kingsville
# success: inserted West Footscray - Tottenham
# success: inserted Yarraville
# success: inserted Bacchus Marsh
# success: inserted Hillside
# success: inserted Melton
# success: inserted Melton South
# success: inserted Melton West
# success: inserted Rockbank - Mount Cottrell
# success: inserted Taylors Hill
# success: inserted Burnside
# success: inserted Burnside Heights
# success: inserted Caroline Springs
# success: inserted Hoppers Crossing - North
# success: inserted Hoppers Crossing - South
# success: inserted Laverton
# success: inserted Tarneit
# success: inserted Truganina
# success: inserted Werribee - South
# success: inserted Wyndham Vale
# success: inserted Point Cook - East
# success: inserted Point Cook - North
# success: inserted Point Cook - South
# success: inserted Werribee - East
# success: inserted Werribee - West
# success: inserted Carrum Downs
# success: inserted Frankston
# success: inserted Frankston North
# success: inserted Frankston South
# success: inserted Langwarrin
# success: inserted Seaford (Vic.)
# success: inserted Skye - Sandhurst
# success: inserted Dromana
# success: inserted Flinders
# success: inserted Hastings - Somers
# success: inserted Mornington
# success: inserted Mount Eliza
# success: inserted Mount Martha
# success: inserted Point Nepean
# success: inserted Rosebud - McCrae
# success: inserted Somerville
# success: inserted Ararat
# success: inserted Ararat Region
# success: inserted Horsham
# success: inserted Horsham Region
# success: inserted Nhill Region
# success: inserted St Arnaud
# success: inserted Stawell
# success: inserted West Wimmera
# success: inserted Yarriambiack
# success: inserted Irymple
# success: inserted Merbein
# success: inserted Mildura Region
# success: inserted Red Cliffs
# success: inserted Mildura - North
# success: inserted Mildura - South
# success: inserted Buloke
# success: inserted Gannawarra
# success: inserted Kerang
# success: inserted Robinvale
# success: inserted Swan Hill
# success: inserted Swan Hill Region
# success: inserted Echuca
# success: inserted Kyabram
# success: inserted Lockington - Gunbower
# success: inserted Rochester
# success: inserted Rushworth
# success: inserted Cobram
# success: inserted Moira
# success: inserted Numurkah
# success: inserted Yarrawonga
# success: inserted Mooroopna
# success: inserted Shepparton - North
# success: inserted Shepparton - South
# success: inserted Shepparton Region - East
# success: inserted Shepparton Region - West
# success: inserted Glenelg (Vic.)
# success: inserted Hamilton (Vic.)
# success: inserted Portland
# success: inserted Southern Grampians
# success: inserted Camperdown
# success: inserted Colac
# success: inserted Colac Region
# success: inserted Corangamite - North
# success: inserted Corangamite - South
# success: inserted Otway
# success: inserted Moyne - East
# success: inserted Moyne - West
# success: inserted Warrnambool - North
# success: inserted Warrnambool - South
# success: inserted Migratory - Offshore - Shipping (Vic.)
# success: inserted No usual address (Vic.)
# success: inserted Alexandra Hills
# success: inserted Belmont - Gumdale
# success: inserted Birkdale
# success: inserted Capalaba
# success: inserted Thorneside
# success: inserted Wellington Point
# success: inserted Cleveland
# success: inserted Ormiston
# success: inserted Redland Bay
# success: inserted Sheldon - Mount Cotton
# success: inserted Thornlands
# success: inserted Victoria Point
# success: inserted Redland Islands
# success: inserted Brisbane Port - Lytton
# success: inserted Manly - Lota
# success: inserted Manly West
# success: inserted Murarrie
# success: inserted Tingalpa
# success: inserted Wakerley
# success: inserted Wynnum
# success: inserted Wynnum West - Hemmant
# success: inserted Bald Hills
# success: inserted Bridgeman Downs
# success: inserted Carseldine
# success: inserted Everton Park
# success: inserted McDowall
# success: inserted Aspley
# success: inserted Chermside
# success: inserted Chermside West
# success: inserted Geebung
# success: inserted Kedron - Gordon Park
# success: inserted Stafford
# success: inserted Stafford Heights
# success: inserted Wavell Heights
# success: inserted Boondall
# success: inserted Brisbane Airport
# success: inserted Eagle Farm - Pinkenba
# success: inserted Northgate - Virginia
# success: inserted Nudgee - Banyo
# success: inserted Nundah
# success: inserted Bracken Ridge
# success: inserted Brighton (Qld)
# success: inserted Deagon
# success: inserted Sandgate - Shorncliffe
# success: inserted Taigum - Fitzgibbon
# success: inserted Zillmere
# success: inserted Camp Hill
# success: inserted Cannon Hill
# success: inserted Carina
# success: inserted Carina Heights
# success: inserted Carindale
# success: inserted Annerley
# success: inserted Coorparoo
# success: inserted Fairfield - Dutton Park
# success: inserted Greenslopes
# success: inserted Holland Park
# success: inserted Holland Park West
# success: inserted Woolloongabba
# success: inserted Yeronga
# success: inserted Eight Mile Plains
# success: inserted Macgregor (Qld)
# success: inserted Mansfield (Qld)
# success: inserted Mount Gravatt
# success: inserted Rochedale - Burbank
# success: inserted Upper Mount Gravatt
# success: inserted Wishart
# success: inserted Coopers Plains
# success: inserted Moorooka
# success: inserted Robertson
# success: inserted Salisbury - Nathan
# success: inserted Tarragindi
# success: inserted Algester
# success: inserted Calamvale - Stretton
# success: inserted Pallara - Willawong
# success: inserted Parkinson - Drewvale
# success: inserted Rocklea - Acacia Ridge
# success: inserted Kuraby
# success: inserted Runcorn
# success: inserted Sunnybank
# success: inserted Sunnybank Hills
# success: inserted Jindalee - Mount Ommaney
# success: inserted Middle Park - Jamboree Heights
# success: inserted Riverhills
# success: inserted Seventeen Mile Rocks - Sinnamon Park
# success: inserted Westlake
# success: inserted Bellbowrie - Moggill
# success: inserted Brookfield - Kenmore Hills
# success: inserted Chapel Hill
# success: inserted Fig Tree Pocket
# success: inserted Kenmore
# success: inserted Pinjarra Hills - Pullenvale
# success: inserted Chelmer - Graceville
# success: inserted Corinda
# success: inserted Indooroopilly
# success: inserted Sherwood
# success: inserted St Lucia
# success: inserted Taringa
# success: inserted Enoggera
# success: inserted Enoggera Reservoir
# success: inserted Keperra
# success: inserted Mitchelton
# success: inserted Mount Coot-tha
# success: inserted The Gap
# success: inserted Upper Kedron - Ferny Grove
# success: inserted Brisbane City
# success: inserted Fortitude Valley
# success: inserted Highgate Hill
# success: inserted Kangaroo Point
# success: inserted New Farm
# success: inserted South Brisbane
# success: inserted Spring Hill
# success: inserted West End
# success: inserted Balmoral
# success: inserted Bulimba
# success: inserted East Brisbane
# success: inserted Hawthorne
# success: inserted Morningside - Seven Hills
# success: inserted Norman Park
# success: inserted Albion
# success: inserted Alderley
# success: inserted Ascot
# success: inserted Clayfield
# success: inserted Grange
# success: inserted Hamilton (Qld)
# success: inserted Hendra
# success: inserted Kelvin Grove - Herston
# success: inserted Newmarket
# success: inserted Newstead - Bowen Hills
# success: inserted Wilston
# success: inserted Windsor
# success: inserted Wooloowin - Lutwyche
# success: inserted Ashgrove
# success: inserted Auchenflower
# success: inserted Bardon
# success: inserted Paddington - Milton
# success: inserted Red Hill (Qld)
# success: inserted Toowong
# success: inserted Brinsmead
# success: inserted Clifton Beach - Kewarra Beach
# success: inserted Freshwater - Stratford
# success: inserted Redlynch
# success: inserted Trinity Beach - Smithfield
# success: inserted Yorkeys Knob - Machans Beach
# success: inserted Bentley Park
# success: inserted Cairns City
# success: inserted Earlville - Bayview Heights
# success: inserted Edmonton
# success: inserted Gordonvale - Trinity
# success: inserted Kanimbla - Mooroobool
# success: inserted Lamb Range
# success: inserted Manoora
# success: inserted Manunda
# success: inserted Mount Sheridan
# success: inserted Westcourt - Bungalow
# success: inserted White Rock
# success: inserted Whitfield - Edge Hill
# success: inserted Woree
# success: inserted Babinda
# success: inserted Innisfail
# success: inserted Johnstone
# success: inserted Tully
# success: inserted Wooroonooran
# success: inserted Yarrabah
# success: inserted Daintree
# success: inserted Port Douglas
# success: inserted Atherton
# success: inserted Herberton
# success: inserted Kuranda
# success: inserted Malanda - Yungaburra
# success: inserted Mareeba
# success: inserted Balonne
# success: inserted Chinchilla
# success: inserted Goondiwindi
# success: inserted Inglewood - Waggamba
# success: inserted Miles - Wandoan
# success: inserted Roma
# success: inserted Roma Region
# success: inserted Tara
# success: inserted Crows Nest - Rosalie
# success: inserted Jondaryan
# success: inserted Millmerran
# success: inserted Pittsworth
# success: inserted Wambo
# success: inserted Clifton - Greenmount
# success: inserted Southern Downs - East
# success: inserted Southern Downs - West
# success: inserted Stanthorpe
# success: inserted Stanthorpe Region
# success: inserted Warwick
# success: inserted Central Highlands - East
# success: inserted Central Highlands - West
# success: inserted Emerald
# success: inserted Berserker
# success: inserted Bouldercombe
# success: inserted Emu Park
# success: inserted Frenchville - Mount Archer
# success: inserted Glenlee - Rockyview
# success: inserted Gracemere
# success: inserted Lakes Creek
# success: inserted Mount Morgan
# success: inserted Norman Gardens
# success: inserted Park Avenue
# success: inserted Parkhurst - Kawana
# success: inserted Rockhampton - West
# success: inserted Rockhampton City
# success: inserted Rockhampton Region - East
# success: inserted Rockhampton Region - North
# success: inserted Rockhampton Region - West
# success: inserted Shoalwater Bay
# success: inserted The Range - Allenstown
# success: inserted Yeppoon
# success: inserted Banana
# success: inserted Biloela
# success: inserted Agnes Water - Miriam Vale
# success: inserted Boyne Island - Tannum Sands
# success: inserted Callemondah
# success: inserted Clinton - New Auckland
# success: inserted Gladstone
# success: inserted Gladstone Hinterland
# success: inserted Kin Kora - Sun Valley
# success: inserted South Trees
# success: inserted Telina - Toolooa
# success: inserted West Gladstone
# success: inserted Broadbeach Waters
# success: inserted Burleigh Heads
# success: inserted Burleigh Waters
# success: inserted Mermaid Beach - Broadbeach
# success: inserted Mermaid Waters
# success: inserted Miami
# success: inserted Coolangatta
# success: inserted Currumbin - Tugun
# success: inserted Currumbin Waters
# success: inserted Elanora
# success: inserted Palm Beach
# success: inserted Arundel
# success: inserted Biggera Waters
# success: inserted Coombabah
# success: inserted Labrador
# success: inserted Paradise Point - Hollywell
# success: inserted Runaway Bay
# success: inserted Guanaba - Springbrook
# success: inserted Tamborine - Canungra
# success: inserted Currumbin Valley - Tallebudgera
# success: inserted Mudgeeraba - Bonogin
# success: inserted Reedy Creek - Andrews
# success: inserted Carrara
# success: inserted Highland Park
# success: inserted Nerang - Mount Nathan
# success: inserted Pacific Pines - Gaven
# success: inserted Worongary - Tallai
# success: inserted Coomera
# success: inserted Helensvale
# success: inserted Hope Island
# success: inserted Jacobs Well - Alberton
# success: inserted Ormeau - Yatala
# success: inserted Oxenford - Maudsland
# success: inserted Pimpama
# success: inserted Upper Coomera - Willow Vale
# success: inserted Clear Island Waters
# success: inserted Merrimac
# success: inserted Robina
# success: inserted Varsity Lakes
# success: inserted Ashmore
# success: inserted Molendinar
# success: inserted Parkwood
# success: inserted Southport - North
# success: inserted Southport - South
# success: inserted Benowa
# success: inserted Bundall
# success: inserted Main Beach
# success: inserted Surfers Paradise
# success: inserted Darra - Sumner
# success: inserted Durack
# success: inserted Forest Lake - Doolandella
# success: inserted Inala - Richlands
# success: inserted Oxley (Qld)
# success: inserted Wacol
# success: inserted Boonah
# success: inserted Esk
# success: inserted Lake Manchester - England Creek
# success: inserted Lockyer Valley - East
# success: inserted Lowood
# success: inserted Rosewood
# success: inserted Brassall
# success: inserted Bundamba
# success: inserted Churchill - Yamanto
# success: inserted Ipswich - Central
# success: inserted Ipswich - East
# success: inserted Ipswich - North
# success: inserted Karalee - Barellan Point
# success: inserted Karana Downs
# success: inserted Leichhardt - One Mile
# success: inserted North Ipswich - Tivoli
# success: inserted Raceview
# success: inserted Ripley
# success: inserted Riverview
# success: inserted Bellbird Park - Brookwater
# success: inserted Camira - Gailes
# success: inserted Carole Park
# success: inserted Collingwood Park - Redbank
# success: inserted Goodna
# success: inserted New Chum
# success: inserted Redbank Plains
# success: inserted Springfield
# success: inserted Springfield Lakes
# success: inserted Beaudesert
# success: inserted Beenleigh
# success: inserted Eagleby
# success: inserted Edens Landing - Holmview
# success: inserted Mount Warren Park
# success: inserted Wolffdene - Bahrs Scrub
# success: inserted Boronia Heights - Park Ridge
# success: inserted Browns Plains
# success: inserted Chambers Flat - Logan Reserve
# success: inserted Crestmead
# success: inserted Greenbank Military Camp
# success: inserted Hillcrest
# success: inserted Marsden
# success: inserted Munruben - Park Ridge South
# success: inserted Regents Park - Heritage Park
# success: inserted Greenbank
# success: inserted Jimboomba
# success: inserted Logan Village
# success: inserted Bethania - Waterford
# success: inserted Byford
# success: inserted Mundijong
# success: inserted Serpentine - Jarrahdale
# success: inserted Como
# success: inserted Manning - Waterford
# success: inserted South Perth - Kensington
# success: inserted Banjup
# success: inserted Bibra Industrial
# success: inserted Bibra Lake
# success: inserted Coogee
# success: inserted Coolbellup
# success: inserted Hamilton Hill
# success: inserted Henderson
# success: inserted North Coogee
# success: inserted South Lake - Cockburn Central
# success: inserted Spearwood
# success: inserted Success - Hammond Park
# success: inserted Yangebup
# success: inserted Beeliar - Wattleup
# success: inserted Jandakot
# success: inserted East Fremantle
# success: inserted Fremantle
# success: inserted Fremantle - South
# success: inserted O'Connor (WA)
# success: inserted Bertram - Wellard (West)
# success: inserted Calista
# success: inserted Hope Valley - Postans
# success: inserted Kwinana Industrial
# success: inserted Parmelia - Orelia
# success: inserted Casuarina - Wandi
# success: inserted Applecross - Ardross
# success: inserted Bateman
# success: inserted Bicton - Palmyra
# success: inserted Booragoon
# success: inserted Bull Creek
# success: inserted Leeming
# success: inserted Melville
# success: inserted Murdoch - Kardinya
# success: inserted Willagee
# success: inserted Winthrop
# success: inserted Baldivis
# success: inserted Cooloongup
# success: inserted Port Kennedy
# success: inserted Rockingham
# success: inserted Rockingham Lakes
# success: inserted Safety Bay - Shoalwater
# success: inserted Singleton - Golden Bay - Secret Harbour
# success: inserted Waikiki
# success: inserted Warnbro
# success: inserted Albany
# success: inserted Albany Region
# success: inserted Bayonet Head - Lower King
# success: inserted Denmark
# success: inserted Gnowangerup
# success: inserted Katanning
# success: inserted Kojonup
# success: inserted Little Grove - Elleker
# success: inserted McKail - Willyung
# success: inserted Plantagenet
# success: inserted Stirling Range National Park
# success: inserted Chittering
# success: inserted Cunderdin
# success: inserted Dowerin
# success: inserted Gingin - Dandaragan
# success: inserted Merredin
# success: inserted Moora
# success: inserted Mukinbudin
# success: inserted Northam
# success: inserted Toodyay
# success: inserted York - Beverley
# success: inserted Brookton
# success: inserted Kulin
# success: inserted Murray
# success: inserted Narrogin
# success: inserted Wagin
# success: inserted Broome
# success: inserted Derby - West Kimberley
# success: inserted Halls Creek
# success: inserted Kununurra
# success: inserted Roebuck
# success: inserted East Pilbara
# success: inserted Newman
# success: inserted Port Hedland
# success: inserted South Hedland
# success: inserted Ashburton (WA)
# success: inserted Karratha
# success: inserted Roebourne
# success: inserted Esperance
# success: inserted Esperance Region
# success: inserted Carnarvon
# success: inserted Exmouth
# success: inserted Boulder
# success: inserted Kalgoorlie
# success: inserted Kalgoorlie - North
# success: inserted Kalgoorlie Airport
# success: inserted Kambalda - Coolgardie - Norseman
# success: inserted Leinster - Leonora
# success: inserted Trafalgar (WA)
# success: inserted Geraldton
# success: inserted Geraldton - East
# success: inserted Geraldton - North
# success: inserted Geraldton - South
# success: inserted Irwin
# success: inserted Meekatharra
# success: inserted Morawa
# success: inserted Northampton - Mullewa - Greenough
# success: inserted Migratory - Offshore - Shipping (WA)
# success: inserted No usual address (WA)
# success: inserted Bridgewater - Gagebrook
# success: inserted Brighton - Pontville
# success: inserted Old Beach - Otago
# success: inserted Bellerive - Rosny
# success: inserted Cambridge
# success: inserted Geilston Bay - Risdon
# success: inserted Howrah - Tranmere
# success: inserted Lindisfarne - Rose Bay
# success: inserted Mornington - Warrane
# success: inserted Risdon Vale
# success: inserted Rokeby
# success: inserted South Arm
# success: inserted Austins Ferry - Granton
# success: inserted Berriedale - Chigwell
# success: inserted Claremont (Tas.)
# success: inserted Derwent Park - Lutana
# success: inserted Glenorchy
# success: inserted Montrose - Rosetta
# success: inserted Moonah
# success: inserted New Norfolk
# success: inserted West Moonah
# success: inserted Kingston - Huntingfield
# success: inserted Kingston Beach - Blackmans Bay
# success: inserted Margate - Snug
# success: inserted Mount Wellington
# success: inserted Taroona - Bonnet Hill
# success: inserted Hobart
# success: inserted Lenah Valley - Mount Stuart
# success: inserted Mount Nelson - Dynnyrne
# success: inserted New Town
# success: inserted Sandy Bay
# success: inserted South Hobart - Fern Tree
# success: inserted West Hobart
# success: inserted Dodges Ferry - Lewisham
# success: inserted Sorell - Richmond
# success: inserted Invermay
# success: inserted Kings Meadows - Punchbowl
# success: inserted Launceston
# success: inserted Legana
# success: inserted Mowbray
# success: inserted Newnham - Mayfield
# success: inserted Newstead
# success: inserted Norwood (Tas.)
# success: inserted Prospect Vale - Blackstone
# success: inserted Ravenswood
# success: inserted Riverside
# success: inserted South Launceston
# success: inserted Summerhill - Prospect
# success: inserted Trevallyn
# success: inserted Waverley - St Leonards
# success: inserted West Launceston
# success: inserted Youngtown - Relbia
# success: inserted Beauty Point - Beaconsfield
# success: inserted Deloraine
# success: inserted Grindelwald - Lanena
# success: inserted Hadspen - Carrick
# success: inserted Westbury
# success: inserted Dilston - Lilydale
# success: inserted George Town
# success: inserted Longford
# success: inserted Northern Midlands
# success: inserted Perth - Evandale
# success: inserted St Helens - Scamander
# success: inserted Flinders and Cape Barren Islands
# success: inserted Scottsdale - Bridport
# success: inserted Central Highlands
# success: inserted Derwent Valley
# success: inserted Southern Midlands
# success: inserted Wilderness - East
# success: inserted Bruny Island - Kettering
# success: inserted Cygnet
# success: inserted Geeveston - Dover
# success: inserted Huonville - Franklin
# success: inserted Forestier - Tasman
# success: inserted Triabunna - Bicheno
# success: inserted Acton - Upper Burnie
# success: inserted Burnie - Ulverstone Region
# success: inserted Burnie - Wivenhoe
# success: inserted Parklands - Camdale
# success: inserted Penguin - Sulphur Creek
# success: inserted Romaine - Havenview
# success: inserted Somerset
# success: inserted Ulverstone
# success: inserted West Ulverstone
# success: inserted Wynyard
# success: inserted Devonport
# success: inserted East Devonport
# success: inserted Latrobe
# success: inserted Miandetta - Don
# success: inserted Port Sorell
# success: inserted Quoiba - Spreyton
# success: inserted Sheffield - Railton
# success: inserted Turners Beach - Forth
# success: inserted King Island
# success: inserted North West
# success: inserted Smithton
# success: inserted Waratah
# success: inserted West Coast (Tas.)
# success: inserted Wilderness - West
# success: inserted Migratory - Offshore - Shipping (Tas.)
# success: inserted No usual address (Tas.)
# success: inserted Darwin Airport
# success: inserted Darwin City
# success: inserted East Point
# success: inserted Fannie Bay - The Gardens
# success: inserted Larrakeyah
# success: inserted Ludmilla - The Narrows
# success: inserted Parap
# success: inserted Stuart Park
# success: inserted Woolner - Bayview - Winnellie
# success: inserted Alawa
# success: inserted Anula
# success: inserted Berrimah
# success: inserted Brinkin - Nakara
# success: inserted Buffalo Creek
# success: inserted Charles Darwin
# success: inserted Coconut Grove
# success: inserted East Arm
# success: inserted Jingili
# success: inserted Karama
# success: inserted Leanyer
# success: inserted Lyons (NT)
# success: inserted Malak - Marrara
# success: inserted Millner
# success: inserted Moil
# success: inserted Nightcliff
# success: inserted Rapid Creek
# success: inserted Tiwi
# success: inserted Wagaman
# success: inserted Wanguri
# success: inserted Wulagi
# success: inserted Howard Springs
# success: inserted Humpty Doo
# success: inserted Koolpinyah
# success: inserted Virginia
# success: inserted Weddell
# success: inserted Bakewell
# success: inserted Driver
# success: inserted Durack - Marlow Lagoon
# success: inserted Gray
# success: inserted Moulden
# success: inserted Palmerston - North
# success: inserted Palmerston - South
# success: inserted Rosebery - Bellamack
# success: inserted Woodroffe
# success: inserted Charles
# success: inserted East Side
# success: inserted Flynn (NT)
# success: inserted Larapinta
# success: inserted Mount Johns
# success: inserted Petermann - Simpson
# success: inserted Ross
# success: inserted Sandover - Plenty
# success: inserted Tanami
# success: inserted Yuendumu - Anmatjere
# success: inserted Barkly
# success: inserted Tennant Creek
# success: inserted Alligator
# success: inserted Daly
# success: inserted Thamarrurr
# success: inserted Tiwi Islands
# success: inserted West Arnhem
# success: inserted Anindilyakwa
# success: inserted East Arnhem
# success: inserted Nhulunbuy
# success: inserted Elsey
# success: inserted Gulf
# success: inserted Katherine
# success: inserted Victoria River
# success: inserted Migratory - Offshore - Shipping (NT)
# success: inserted No usual address (NT)
# success: inserted Aranda
# success: inserted Belconnen
# success: inserted Bruce
# success: inserted Charnwood
# success: inserted Cook
# success: inserted Dunlop
# success: inserted Evatt
# success: inserted Florey
# success: inserted Flynn (ACT)
# success: inserted Fraser
# success: inserted Giralang
# success: inserted Gooromon
# success: inserted Hawker
# success: inserted Higgins
# success: inserted Holt
# success: inserted Kaleen
# success: inserted Latham
# success: inserted Lawson
# success: inserted Macgregor (ACT)
# success: inserted Macquarie
# success: inserted McKellar
# success: inserted Melba
# success: inserted Page
# success: inserted Scullin
# success: inserted Spence
# success: inserted Weetangera
# success: inserted Molonglo Corridor
# success: inserted West Belconnen
# success: inserted Hume
# success: inserted Kowen
# success: inserted Canberra East
# success: inserted Canberra Airport
# success: inserted Majura
# success: inserted Amaroo
# success: inserted Bonner
# success: inserted Casey
# success: inserted Crace
# success: inserted Forde
# success: inserted Franklin
# success: inserted Gungahlin
# success: inserted Hall
# success: inserted Harrison
# success: inserted Mitchell
# success: inserted Ngunnawal
# success: inserted Nicholls
# success: inserted Palmerston
# success: inserted Gungahlin - East
# success: inserted Gungahlin - West
# success: inserted Jacka
# success: inserted Kenny
# success: inserted Moncrieff
# success: inserted Taylor
# success: inserted Throsby
# success: inserted Acton
# success: inserted Ainslie
# success: inserted Braddon
# success: inserted Civic
# success: inserted Dickson
# success: inserted Downer
# success: inserted Hackett
# success: inserted Lyneham
# success: inserted O'Connor (ACT)
# success: inserted Turner
# success: inserted Watson
# success: inserted Black Mountain
# success: inserted Campbell
# success: inserted Duntroon
# success: inserted Parkes (ACT) - North
# success: inserted Reid
# success: inserted Russell
# success: inserted Deakin
# success: inserted Forrest
# success: inserted Griffith (ACT)
# success: inserted Lake Burley Griffin
# success: inserted Narrabundah
# success: inserted Parkes (ACT) - South
# success: inserted Red Hill (ACT)
# success: inserted Yarralumla
# success: inserted Barton
# success: inserted Fyshwick
# success: inserted Kingston (ACT)
# success: inserted Banks
# success: inserted Bonython
# success: inserted Calwell
# success: inserted Chisholm
# success: inserted Conder
# success: inserted Fadden
# success: inserted Gilmore
# success: inserted Gordon (ACT)
# success: inserted Gowrie (ACT)
# success: inserted Greenway
# success: inserted Isabella Plains
# success: inserted Kambah
# success: inserted Macarthur
# success: inserted Monash
# success: inserted Mount Taylor
# success: inserted Oxley (ACT)
# success: inserted Richardson
# success: inserted Theodore
# success: inserted Tuggeranong
# success: inserted Wanniassa
# success: inserted Tuggeranong - West
# success: inserted Chapman
# success: inserted Duffy
# success: inserted Fisher
# success: inserted Holder
# success: inserted Rivett
# success: inserted Stirling
# success: inserted Waramanga
# success: inserted Weston
# success: inserted Scrivener
# success: inserted Chifley
# success: inserted Curtin
# success: inserted Farrer
# success: inserted Garran
# success: inserted Hughes
# success: inserted Isaacs
# success: inserted Lyons (ACT)
# success: inserted Mawson
# success: inserted O'Malley
# success: inserted Pearce
# success: inserted Phillip
# success: inserted Torrens
# success: inserted Arboretum
# success: inserted Coombs
# success: inserted Denman Prospect
# success: inserted Molonglo
# success: inserted Molonglo - North
# success: inserted Wright
# success: inserted ACT - South West
# success: inserted Namadgi
# success: inserted Migratory - Offshore - Shipping (ACT)
# success: inserted No usual address (ACT)
# success: inserted Christmas Island
# success: inserted Cocos (Keeling) Islands
# success: inserted Jervis Bay
# success: inserted Norfolk Island
# success: inserted Migratory - Offshore - Shipping (OT)
# success: inserted No usual address (OT)

# %% [markdown]
# **Check what data got loaded**

# %%
query = "SELECT COUNT(*) FROM sydney_areas"
result= pgquery(conn, query, returntype='dict')
from pprint import pprint 
print(result)
# Out:
# [RealDictRow([('count', 2310)])]

# %%
# Out:
#   File "<ipython-input-12-43a342ce5eed>", line 1
#     jupyter notebook --NotebookApp.iopub_data_rate_limit=1000000
#                    ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Task1 4.

# %%
# Lookup of a given address via OpenStreetMap Web-API:
import requests
import json
base_url = 'http://soit-app-pro-4.ucc.usyd.edu.au:3000/api/v1/json'
my_params= {'data': 'origin,destinations','format':'json','limit':'1'}
response = requests.get(base_url, params = my_params)

# let us see the raw JSON response
# print(json.dumps(response.json(), indent=4, sort_keys=False))

# %% [markdown]
# ## Task2 1. Finding the measures

# %% [markdown]
# **Population density**
# population divided by neighbourhood's land area

# %%
conn.execute("""
    SELECT 
""")

# %%
# conn.execute("DROP TABLE IF EXISTS measures_for_vulnerability_score")
# measures_for_vulnerability_score_schma = """CREATE TABLE IF NOT EXISTS measures_for_vulnerability_score (
#                         area_id int,
#                         area_name varchar(50),
#                         land_area float,
#                         population int,
#                         number_of_dwellings int,
#                         number_of_businesses int,
#                         median_annual_household_income int,
#                         avg_monthly_rent int,
#                         primary key(area_id)
#                         )"""
# conn.execute(neighbourhoods_schma)
# print(db.table_names())

# %% [markdown]
# **population_density**

# %%
conn.execute("""
    select (population/land_area) as "population density" from neighbourhoods;
""")

# %% [markdown]
# **改column名字**
# **population_age**

# %%
conn.execute("""
    SELECT n.index, n.area_id, n.population, (p."70-74" + p."75-79" + p."80-84" + p."85_and_over") AS "population_over_70", 
    n.population/(p."70-74" + p."75-79" + p."80-84" + p."85_and_over") AS "percentage_age_over_70"
    FROM neighbourhoods n JOIN populations p ON (n.area_id = p.area_id)
    WHERE p."70-74" > 0 OR p."75-79" > 0 OR p."80-84" > 0 OR p."85_and_over" > 0
""")

# %% [markdown]
# **healthservice_density**

# %% [markdown]
# **hospitalbed_density**

# %%
conn.execute("""
    GRANT ALL PRIVILEGES ON ALL TABLES IN SCHEMA public to y20s1d2x01_chou2825
""")
# Out:
# ---------------------------------------------------------------------------
# InsufficientPrivilege                     Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#
# InsufficientPrivilege: permission denied for table neighbourhood_population_with_age_distribution
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-35-a418a911f427> in <module>
#       1 conn.execute("""
#       2     GRANT ALL PRIVILEGES ON ALL TABLES IN SCHEMA public to y20s1d2x01_chou2825
# ----> 3 """)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     980         """
#     981         if isinstance(object_, util.string_types[0]):
# --> 982             return self._execute_text(object_, multiparams, params)
#     983         try:
#     984             meth = object_._execute_on_connection
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1153             parameters,
#    1154             statement,
# -> 1155             parameters,
#    1156         )
#    1157         if self._has_events or self.engine._has_events:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1251         except BaseException as e:
#    1252             self._handle_dbapi_exception(
# -> 1253                 e, statement, parameters, cursor, context
#    1254             )
#    1255
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1471                 util.raise_from_cause(newraise, exc_info)
#    1472             elif should_wrap:
# -> 1473                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1474             else:
#    1475                 util.reraise(*exc_info)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     396     exc_type, exc_value, exc_tb = exc_info
#     397     cause = exc_value if exc_value is not exception else None
# --> 398     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     399
#     400
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     150             value.__cause__ = cause
#     151         if value.__traceback__ is not tb:
# --> 152             raise value.with_traceback(tb)
#     153         raise value
#     154
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                 if not evt_handled:
#    1248                     self.dialect.do_execute(
# -> 1249                         cursor, statement, parameters, context
#    1250                     )
#    1251         except BaseException as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     578
#     579     def do_execute(self, cursor, statement, parameters, context=None):
# --> 580         cursor.execute(statement, parameters)
#     581
#     582     def do_execute_no_params(self, cursor, statement, context=None):
#
# ProgrammingError: (psycopg2.errors.InsufficientPrivilege) permission denied for table neighbourhood_population_with_age_distribution
#
# [SQL:
#     GRANT ALL PRIVILEGES ON ALL TABLES IN SCHEMA public to y20s1d2x01_chou2825
# ]
# (Background on this error at: http://sqlalche.me/e/f405)

# %%
conn.close()
db.dispose()
